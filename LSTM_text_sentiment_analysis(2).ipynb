# %% [markdown]
# <a href="https://colab.research.google.com/github/MAHMUD722025/Lstm-text-sentiment-analysis-./blob/main/LSTM_text_sentiment_analysis(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import pandas as pd
from google.colab import drive

#Load data
drive.mount('/content/drive')
df = pd.read_excel('/content/drive/MyDrive/movie_reviews_50000.xlsx')
texts = df['movie_reviews'].astype(str).str.lower().values
labels = df['review_status'].map({'good':1,'bad':0}).values

#Tokenize and pad
tokenizer = Tokenizer(num_words=10000, oov_token="<OOV>")
tokenizer.fit_on_texts(texts)
sequences = tokenizer.texts_to_sequences(texts)
padded = pad_sequences(sequences, maxlen=100)

#Model
model = Sequential()
model.add(Embedding(input_dim=10000, output_dim=64, input_length=100))
model.add(Bidirectional(LSTM(64, return_sequences=True)))
model.add(Dropout(0.3))
model.add(Bidirectional(LSTM(32)))
model.add(Dropout(0.3))
model.add(Dense(1, activation='sigmoid'))

#Compile and train
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(padded, labels, epochs=10, batch_size=32)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Epoch 1/10
# /usr/local/lib/python3.13/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 35s 20ms/step - accuracy: 0.9952 - loss: 0.0123
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 33s 21ms/step - accuracy: 1.0000 - loss: 8.4620e-06
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 32s 21ms/step - accuracy: 1.0000 - loss: 3.0415e-06
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 32s 20ms/step - accuracy: 1.0000 - loss: 1.4815e-06
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 41s 21ms/step - accuracy: 1.0000 - loss: 7.2740e-07
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 33s 21ms/step - accuracy: 1.0000 - loss: 3.5946e-07
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 32s 20ms/step - accuracy: 1.0000 - loss: 1.7716e-07
# Epoch 8/10
# ...

# %%
from tensorflow.keras.datasets import imdb
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Load data (Drive-এর বদলে সরাসরি IMDB)
(sequences, labels), _ = imdb.load_data(num_words=10000)

# Pad
padded = pad_sequences(sequences, maxlen=100)

# Model
model = Sequential()
model.add(Embedding(input_dim=10000, output_dim=64, input_length=100))
model.add(Bidirectional(LSTM(64, return_sequences=True)))
model.add(Dropout(0.3))
model.add(Bidirectional(LSTM(32)))
model.add(Dropout(0.3))
model.add(Dense(1, activation='sigmoid'))

# Compile and train (আপনার মতো সিম্পল রাখা হলো)
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(padded, labels, epochs=10, batch_size=32)
# Out:
# ...
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# /usr/local/lib/python3.13/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 25s 22ms/step - accuracy: 0.7998 - loss: 0.4236
# Epoch 2/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 21ms/step - accuracy: 0.8991 - loss: 0.2522
# Epoch 3/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 20ms/step - accuracy: 0.9376 - loss: 0.1687
# Epoch 4/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 17s 22ms/step - accuracy: 0.9652 - loss: 0.0998
# Epoch 5/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 20ms/step - accuracy: 0.9773 - loss: 0.0647
# Epoch 6/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.9852 - loss: 0.0440
# Epoch 7/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.9913 - loss: 0.0278
# Epoch 8/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 20ms/step - accuracy: 0.9927 - loss: 0.0219
# Epoch 9/10
# ...

# %%
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences

# ১. IMDB-এর শব্দ থেকে নম্বরের ম্যাপ (Word Index) নেওয়া
word_index = imdb.get_word_index()

sentence = "good movie. recommended. adorable acting of my favourite actor".lower()

# ২. বাক্যটিকে টোকেনাইজ (শব্দ থেকে নম্বরে রূপান্তর) করা
words = sentence.split()
# IMDB ডেটাসেটে ১ = Start Token, ২ = OOV Token, এবং ৩ থেকে মূল শব্দ শুরু হয় (+3 করা লাগে)
seq = [[word_index.get(w, 2) + 3 for w in words]]

# ৩. প্যাডিং করা
padded_seq = pad_sequences(seq, maxlen=100)

# ৪. প্রেডিকশন
prediction = model.predict(padded_seq)[0][0]

print(f"Prediction Score: {prediction:.4f}")
print("Positive review 😇" if prediction >= 0.5 else "Negative review 😡")
# Out:
# ...
# 1641221/1641221 ━━━━━━━━━━━━━━━━━━━━ 1s 1us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step
# Prediction Score: 1.0000
# Positive review 😇

# %%
from google.colab import drive

#Load data
drive.mount('/content/drive')
model.save('/content/drive/MyDrive/lstm_model.keras')

word_index = imdb.get_word_index()
# Out:
# Mounted at /content/drive

# %%
from tensorflow.keras.models import load_model

l_model = load_model('/content/drive/MyDrive/lstm_model.keras')

# %%
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences

# ১. IMDB-এর শব্দ থেকে নম্বরের ম্যাপ (Word Index) নেওয়া
word_index = imdb.get_word_index()

sentence = "worst movie i have ever watched in my life. not recommended. acting of the actors seems weak. totally a time waste!".lower()

# ২. বাক্যটিকে টোকেনাইজ (শব্দ থেকে নম্বরে রূপান্তর) করা
words = sentence.split()
# IMDB ডেটাসেটে ১ = Start Token, ২ = OOV Token, এবং ৩ থেকে মূল শব্দ শুরু হয় (+3 করা লাগে)
seq = [[word_index.get(w, 2) + 3 for w in words]]

# ৩. প্যাডিং করা
padded_seq = pad_sequences(seq, maxlen=100)

# ৪. প্রেডিকশন
prediction = l_model.predict(padded_seq)[0][0]

print(f"Prediction Score: {prediction:.4f}")
print("Positive review 😇" if prediction >= 0.5 else "Negative review 😡")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Prediction Score: 0.0002
# Negative review 😡

# %%
l_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, 100, 64)        │       640,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 100, 128)       │        66,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 100, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 64)             │        41,216 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ...
